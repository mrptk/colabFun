# %%
print("hello world")
# Out:
# hello world

# %%
import tensorflow as tf

# %%
mat = tf.Variable([[25., 2.], [3, 4]])

# %%
tf.print(mat)
# Out:
# [[25 2]
#  [3 4]]

# %%
tf.linalg.det(mat)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=94.00001525878906>

# %%
mat1 = tf.Variable([[-2., 0.], [0., -2.]])

# %%
tf.print(mat1)
tf.linalg.det(mat1)
# Out:
# [[-2 0]
#  [0 -2]]
# <tf.Tensor: shape=(), dtype=float32, numpy=4.0>

# %%
mat2 = tf.Variable([[2., 1., -3.], [4., -5., 2.], [0., -1., 3.]])
tf.print(mat2)
tf.linalg.det(mat2)
# Out:
# [[2 1 -3]
#  [4 -5 2]
#  [0 -1 3]]
# <tf.Tensor: shape=(), dtype=float32, numpy=-25.99999237060547>
